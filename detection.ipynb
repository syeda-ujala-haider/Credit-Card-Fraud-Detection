# %% [markdown]
# # Work Flow

# %% [markdown]
# Credit Card Data -->Data Pre Processing-->Data Analysis-->Train test split-->Logistic regression model--->Evaluation

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
import seaborn as sns
from imblearn.over_sampling import SMOTE

# %%
credit_card_data=pd.read_csv("creditcard.csv")

# %%
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_card_data.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
#checkin number of missing values in each columns
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
 credit_card_data["Class"].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# This dataset is highly unbalanced

# %% [markdown]
# 0-->Normal
# 1-->fraud

# %%
#separating the data for analysis
legit=credit_card_data[credit_card_data.Class==0]
fraud=credit_card_data[credit_card_data.Class==1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (284315, 31)
# (492, 31)

# %%
X1=credit_card_data.drop(columns="Class",axis=1)
Y1=credit_card_data["Class"]

# %%
#statistical measures of the data
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
#camparing the values for both transaction
credit_card_data.groupby("Class").mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# Under sampling
# build a sample data containing similar distribution of normal transactions and fraudulent transactions

# %% [markdown]
# number of fruedeland transactions --->492

# %%
legit_sample=legit.sample(n=492)

# %%
#concatenate two dataframes
new_dataset=pd.concat([legit_sample,fraud],axis=0)

# %%
new_dataset.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 40192    40131.0 -0.094996 -0.141301  1.827392 -0.718622 -0.797169  0.038625
# 226957  144875.0  1.314275 -2.357490 -0.405270 -0.240198 -1.768136 -0.162270
# 118594   75140.0  1.274797  0.134625  0.175297  0.316727 -0.072007 -0.208877
# 210729  138100.0  2.116612  0.314710 -2.577999  0.439968  0.964784 -1.211684
# 64605    51222.0 -0.962121  1.476652  1.126513  1.369787 -0.090311  0.151027
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 40192   0.233817 -0.073556  1.344134  ...  0.254128  1.074670 -0.010621
# 226957 -0.639820 -0.152097  0.414008  ...  0.230726  0.036230 -0.052379
# 118594 -0.098056  0.027570 -0.069581  ... -0.266693 -0.832113  0.028693
# 210729  0.710225 -0.439835  0.109118  ...  0.026946  0.265798 -0.024670
# 64605  -0.042526 -1.592793 -0.012714  ...  1.503926 -0.238866  0.100603
#
# ...

# %%
new_dataset.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 279863 -0.882850  0.697211 -2.064945  ...  0.778584 -0.319189  0.639419
# 280143 -1.413170  0.248525 -1.127396  ...  0.370612  0.028234 -0.145640
# 280149 -2.234739  1.210158 -0.652250  ...  0.751826  0.834108  0.190944
# 281144 -2.208002  1.058733 -1.632333  ...  0.583276 -0.269209 -0.456108
# 281674  0.223050 -0.068384  0.577829  ... -0.164350 -0.295135 -0.072173
#
# ...

# %%
new_dataset["Class"].value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %%
new_dataset.groupby("Class").mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      90463.371951  0.027780  0.076716  0.151665 -0.163312 -0.025633
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.046729 -0.016911  0.006639  0.001285  ... -0.011236  0.023628
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.016732 -0.001114 -0.020094 -0.020960  0.016332  0.000519 -0.006987
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       68.527683
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# Splitting a data into features and target

# %%
X=new_dataset.drop(columns="Class",axis=1)
Y=new_dataset["Class"]

# %%
print(X)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 40192    40131.0 -0.094996 -0.141301  1.827392 -0.718622 -0.797169  0.038625
# 226957  144875.0  1.314275 -2.357490 -0.405270 -0.240198 -1.768136 -0.162270
# 118594   75140.0  1.274797  0.134625  0.175297  0.316727 -0.072007 -0.208877
# 210729  138100.0  2.116612  0.314710 -2.577999  0.439968  0.964784 -1.211684
# 64605    51222.0 -0.962121  1.476652  1.126513  1.369787 -0.090311  0.151027
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
print(Y)
# Out:
# 40192     0
# 226957    0
# 118594    0
# 210729    0
# 64605     0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 984, dtype: int64

# %% [markdown]
# Splitting data into test and train

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,stratify=Y,random_state=2)

# %% [markdown]
# Logistic Regression model

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)  # fit_transform nahi, sirf transform

model = LogisticRegression(max_iter=1000)
model.fit(X_train_scaled, Y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %% [markdown]
# Accuracy score

# %%
#with training data
X_train_prediction=model.predict(X_train_scaled)
data_accuracy=accuracy_score(X_train_prediction,Y_train)

# %%
data_accuracy
# Out:
# 0.9542566709021602

# %%
X_test_prediction=model.predict(X_test_scaled)
data_accuracy=accuracy_score(Y_test, X_test_prediction)

# %%
data_accuracy
# Out:
# 0.9289340101522843

# %%
cm = confusion_matrix(Y_test, X_test_prediction)
sns.heatmap(cm, annot=True, fmt='d')
plt.title('Confusion Matrix')
plt.show()

# %%
# Logistic Regression - proper evaluation
print("=" * 40)
print("LOGISTIC REGRESSION RESULTS")
print("=" * 40)
print(classification_report(Y_test, X_test_prediction))
# Out:
# ...
# LOGISTIC REGRESSION RESULTS
# ...
#               precision    recall  f1-score   support
#
#            0       0.88      0.99      0.93        99
#            1       0.99      0.87      0.92        98
#
#     accuracy                           0.93       197
#    macro avg       0.94      0.93      0.93       197
# weighted avg       0.94      0.93      0.93       197

# %%
# Random Forest Model
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, Y_train)  

rf_test_prediction = rf_model.predict(X_test)

print("=" * 40)
print("RANDOM FOREST RESULTS")
print("=" * 40)
print(classification_report(Y_test, rf_test_prediction))
# Out:
# ...
# RANDOM FOREST RESULTS
# ...
#               precision    recall  f1-score   support
#
#            0       0.88      0.98      0.93        99
#            1       0.98      0.87      0.92        98
#
#     accuracy                           0.92       197
#    macro avg       0.93      0.92      0.92       197
# weighted avg       0.93      0.92      0.92       197

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

# Logistic Regression
cm_lr = confusion_matrix(Y_test, X_test_prediction)
sns.heatmap(cm_lr, annot=True, fmt='d', ax=axes[0], cmap='Blues')
axes[0].set_title('Logistic Regression')
axes[0].set_xlabel('Predicted')
axes[0].set_ylabel('Actual')

# Random Forest
cm_rf = confusion_matrix(Y_test, rf_test_prediction)
sns.heatmap(cm_rf, annot=True, fmt='d', ax=axes[1], cmap='Greens')
axes[1].set_title('Random Forest')
axes[1].set_xlabel('Predicted')
axes[1].set_ylabel('Actual')

plt.tight_layout()
plt.show()

# %% [markdown]
# # USING SMOTE

# %%
# — split FIRST, on original data
X_train_orig, X_test_orig, Y_train_orig, Y_test_orig = train_test_split(
    X1, Y1, test_size=0.2, stratify=Y1, random_state=42
)

# SMOTE only on training portion
smote = SMOTE(random_state=42)
X_train_s, Y_train_s = smote.fit_resample(X_train_orig, Y_train_orig)

print("Before SMOTE:", Y_train_orig.value_counts().to_dict())
print("After SMOTE:", pd.Series(Y_train_s).value_counts().to_dict())

# Test set = untouched, real, imbalanced
X_test_s, Y_test_s = X_test_orig, Y_test_orig
# Out:
# Before SMOTE: {0: 227451, 1: 394}
# After SMOTE: {0: 227451, 1: 227451}

# %%
scaler2 = StandardScaler()
X_train_s_scaled = scaler2.fit_transform(X_train_s)
X_test_s_scaled = scaler2.transform(X_test_s)

# %%
# Logistic Regression
lr_smote = LogisticRegression(max_iter=1000)
lr_smote.fit(X_train_s_scaled, Y_train_s)
lr_pred = lr_smote.predict(X_test_s_scaled)

# %%
# Random Forest
rf_smote = RandomForestClassifier(n_estimators=100, random_state=42)
rf_smote.fit(X_train_s, Y_train_s)
rf_pred = rf_smote.predict(X_test_s)

# %%
print("LOGISTIC REGRESSION - SMOTE")
print(classification_report(Y_test_s, lr_pred))

print("RANDOM FOREST - SMOTE")
print(classification_report(Y_test_s, rf_pred))
# Out:
# LOGISTIC REGRESSION - SMOTE
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     56864
#            1       0.13      0.90      0.23        98
#
#     accuracy                           0.99     56962
#    macro avg       0.57      0.94      0.61     56962
# weighted avg       1.00      0.99      0.99     56962
#
# RANDOM FOREST - SMOTE
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.84      0.83      0.83        98
#
#     accuracy                           1.00     56962
#    macro avg       0.92      0.91      0.92     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

sns.heatmap(confusion_matrix(Y_test_s, lr_pred), 
            annot=True, fmt='d', ax=axes[0], cmap='Blues')
axes[0].set_title('LR - SMOTE')
axes[0].set_xlabel('Predicted')
axes[0].set_ylabel('Actual')

sns.heatmap(confusion_matrix(Y_test_s, rf_pred), 
            annot=True, fmt='d', ax=axes[1], cmap='Greens')
axes[1].set_title('RF - SMOTE')
axes[1].set_xlabel('Predicted')
axes[1].set_ylabel('Actual')

plt.tight_layout()
plt.show()
